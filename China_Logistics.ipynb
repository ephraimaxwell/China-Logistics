# %%
#Importing Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
#Loading and reading the dataset
log1 = pd.read_csv('China_Cross_Border_Ecommerce_Logistics_Dataset.csv')
log1
# Out:
#         shipment_id       order_id transaction_date       platform_name  \
# 0     CN-SHP-100000  CN-ORD-500000       2024-04-12  TikTok Shop Global
# 1     CN-SHP-100001  CN-ORD-500001       2025-03-11                Temu
# 2     CN-SHP-100002  CN-ORD-500002       2024-09-27                Temu
# 3     CN-SHP-100003  CN-ORD-500003       2024-04-16   SHEIN Marketplace
# 4     CN-SHP-100004  CN-ORD-500004       2024-03-12                Temu
# ...             ...            ...              ...                 ...
# 6995  CN-SHP-106995  CN-ORD-506995       2025-12-12        JD Worldwide
# 6996  CN-SHP-106996  CN-ORD-506996       2024-11-03       Made-in-China
# 6997  CN-SHP-106997  CN-ORD-506997       2025-09-21        JD Worldwide
# 6998  CN-SHP-106998  CN-ORD-506998       2024-02-15       Made-in-China
# 6999  CN-SHP-106999  CN-ORD-506999       2024-10-28   SHEIN Marketplace
#
#          order_channel origin_city_china origin_province_china  \
# ...

# %%
#Reading the first 5 rows of the data
log1.head()
# Out:
#      shipment_id       order_id transaction_date       platform_name  \
# 0  CN-SHP-100000  CN-ORD-500000       2024-04-12  TikTok Shop Global
# 1  CN-SHP-100001  CN-ORD-500001       2025-03-11                Temu
# 2  CN-SHP-100002  CN-ORD-500002       2024-09-27                Temu
# 3  CN-SHP-100003  CN-ORD-500003       2024-04-16   SHEIN Marketplace
# 4  CN-SHP-100004  CN-ORD-500004       2024-03-12                Temu
#
#       order_channel origin_city_china origin_province_china  \
# 0  Wholesale Portal          Hangzhou              Zhejiang
# 1  Wholesale Portal           Tianjin               Tianjin
# 2  Wholesale Portal            Ningbo              Zhejiang
# 3  Wholesale Portal          Shanghai              Shanghai
# 4       Marketplace          Shanghai              Shanghai
#
#                 warehouse_type customs_port_china   destination_country  ...  \
# 0             Bonded Warehouse   Shanghai Customs        United Kingdom  ...
# ...

# %%
#Reading the last 5 rows of the data
log1.tail()
# Out:
#         shipment_id       order_id transaction_date      platform_name  \
# 6995  CN-SHP-106995  CN-ORD-506995       2025-12-12       JD Worldwide
# 6996  CN-SHP-106996  CN-ORD-506996       2024-11-03      Made-in-China
# 6997  CN-SHP-106997  CN-ORD-506997       2025-09-21       JD Worldwide
# 6998  CN-SHP-106998  CN-ORD-506998       2024-02-15      Made-in-China
# 6999  CN-SHP-106999  CN-ORD-506999       2024-10-28  SHEIN Marketplace
#
#      order_channel origin_city_china origin_province_china  \
# 6995   Marketplace              Yiwu              Zhejiang
# 6996    Mobile App         Guangzhou             Guangdong
# 6997   Marketplace         Guangzhou             Guangdong
# 6998     Web Store         Guangzhou             Guangdong
# 6999   Marketplace            Ningbo              Zhejiang
#
#                    warehouse_type customs_port_china destination_country  ...  \
# 6995  Regional Fulfillment Center   Hangzhou Customs       United States  ...
# ...

# %%
#Reading the statistics summary of the data for numerical variables
log1.describe().T
# Out:
#                                      count         mean          std      min  \
# item_quantity                       7000.0     7.993571     4.313323    1.000
# package_weight_kg                   7000.0     3.894013     2.559543    0.200
# package_volume_cbm                  7000.0     0.059949     0.046575    0.001
# order_value_cny                     7000.0  1302.015931   729.693953   80.000
# declared_value_usd                  7000.0   184.757723   103.608171   11.130
# warehouse_inventory_level           7000.0  7515.717857  4329.864988  120.000
# warehouse_capacity_utilization_pct  7000.0    71.651587    13.511979   35.000
# inventory_availability_pct          7000.0    74.887440     9.215121   42.760
# picking_time_min                    7000.0    24.479103     7.852544    4.000
# packing_time_min                    7000.0    15.409490     5.005761    3.000
# vehicle_capacity_kg                 7000.0  2395.928571  2685.722756  500.000
# ...

# %%
#Reading the statistcs summary of the categorical variables 
log1.describe(include = 'O').T
# Out:
#                                   count unique                   top  freq
# shipment_id                        7000   7000         CN-SHP-100000     1
# order_id                           7000   7000         CN-ORD-500000     1
# transaction_date                   7000    730            2025-12-26    22
# platform_name                      7000      8                  Temu   917
# order_channel                      7000      5      Wholesale Portal  1435
# origin_city_china                  7000     12               Chengdu   646
# origin_province_china              7000      9              Zhejiang  1734
# warehouse_type                     7000      5   Port-side Warehouse  1436
# customs_port_china                 7000      9       Qingdao Customs   861
# destination_country                7000     18         United States  1087
# destination_region                 7000      7                Europe  2613
# ...

# %%
#Checking the length of the data
log1.shape
# Out:
# (7000, 50)

# %%
#Checking the summary of the data
log1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   shipment_id                         7000 non-null   object
#  1   order_id                            7000 non-null   object
#  2   transaction_date                    7000 non-null   object
#  3   platform_name                       7000 non-null   object
#  4   order_channel                       7000 non-null   object
#  5   origin_city_china                   7000 non-null   object
#  6   origin_province_china               7000 non-null   object
#  7   warehouse_type                      7000 non-null   object
#  8   customs_port_china                  7000 non-null   object
#  9   destination_country                 7000 non-null   object
#  10  destination_region                  7000 non-null   object
# ...

# %% [markdown]
# # Data Preparation / Cleaning

# %%
#Saving a copy of the original dataset for future use
log = log1.copy(deep = True)
log
# Out:
#         shipment_id       order_id transaction_date       platform_name  \
# 0     CN-SHP-100000  CN-ORD-500000       2024-04-12  TikTok Shop Global
# 1     CN-SHP-100001  CN-ORD-500001       2025-03-11                Temu
# 2     CN-SHP-100002  CN-ORD-500002       2024-09-27                Temu
# 3     CN-SHP-100003  CN-ORD-500003       2024-04-16   SHEIN Marketplace
# 4     CN-SHP-100004  CN-ORD-500004       2024-03-12                Temu
# ...             ...            ...              ...                 ...
# 6995  CN-SHP-106995  CN-ORD-506995       2025-12-12        JD Worldwide
# 6996  CN-SHP-106996  CN-ORD-506996       2024-11-03       Made-in-China
# 6997  CN-SHP-106997  CN-ORD-506997       2025-09-21        JD Worldwide
# 6998  CN-SHP-106998  CN-ORD-506998       2024-02-15       Made-in-China
# 6999  CN-SHP-106999  CN-ORD-506999       2024-10-28   SHEIN Marketplace
#
#          order_channel origin_city_china origin_province_china  \
# ...

# %%
#Checking the summary of the copied dataset
log.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   shipment_id                         7000 non-null   object
#  1   order_id                            7000 non-null   object
#  2   transaction_date                    7000 non-null   object
#  3   platform_name                       7000 non-null   object
#  4   order_channel                       7000 non-null   object
#  5   origin_city_china                   7000 non-null   object
#  6   origin_province_china               7000 non-null   object
#  7   warehouse_type                      7000 non-null   object
#  8   customs_port_china                  7000 non-null   object
#  9   destination_country                 7000 non-null   object
#  10  destination_region                  7000 non-null   object
# ...

# %%
#Checking the categorical variables in the dataset
log.select_dtypes('O').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   shipment_id                        7000 non-null   object
#  1   order_id                           7000 non-null   object
#  2   transaction_date                   7000 non-null   object
#  3   platform_name                      7000 non-null   object
#  4   order_channel                      7000 non-null   object
#  5   origin_city_china                  7000 non-null   object
#  6   origin_province_china              7000 non-null   object
#  7   warehouse_type                     7000 non-null   object
#  8   customs_port_china                 7000 non-null   object
#  9   destination_country                7000 non-null   object
#  10  destination_region                 7000 non-null   object
# ...

# %%
#checking the values in the variable platform_name
log.platform_name.value_counts()
# Out:
# platform_name
# Temu                  917
# Made-in-China         905
# JD Worldwide          882
# SHEIN Marketplace     876
# DHgate                871
# Alibaba Global        861
# TikTok Shop Global    856
# AliExpress            832
# Name: count, dtype: int64

# %%
#Checking the values in the variable order_channel
log.order_channel.value_counts()
# Out:
# order_channel
# Wholesale Portal    1435
# Web Store           1417
# Mobile App          1404
# Social Commerce     1381
# Marketplace         1363
# Name: count, dtype: int64

# %%
#Checking the values in the variable origin_city_china
log.origin_city_china.value_counts()
# Out:
# origin_city_china
# Chengdu      646
# Suzhou       600
# Shanghai     597
# Qingdao      594
# Ningbo       593
# Yiwu         583
# Xiamen       578
# Shenzhen     569
# Guangzhou    567
# Hangzhou     558
# Zhengzhou    558
# Tianjin      557
# Name: count, dtype: int64

# %%
#Checking the values in the variable origin_province_china
log.origin_province_china.value_counts()
# Out:
# origin_province_china
# Zhejiang     1734
# Guangdong    1136
# Sichuan       646
# Jiangsu       600
# Shanghai      597
# Shandong      594
# Fujian        578
# Henan         558
# Tianjin       557
# Name: count, dtype: int64

# %%
#Checking the values in the variable warehouse_type
log.warehouse_type.value_counts()
# Out:
# warehouse_type
# Port-side Warehouse            1436
# Bonded Warehouse               1428
# Regional Fulfillment Center    1398
# Export Warehouse               1394
# Smart Sorting Center           1344
# Name: count, dtype: int64

# %%
log1.isnull().sum()
# Out:
# shipment_id                           0
# order_id                              0
# transaction_date                      0
# platform_name                         0
# order_channel                         0
# origin_city_china                     0
# origin_province_china                 0
# warehouse_type                        0
# customs_port_china                    0
# destination_country                   0
# destination_region                    0
# logistics_provider                    0
# transport_mode                        0
# product_category                      0
# payment_method                        0
# customer_priority_level               0
# item_quantity                         0
# package_weight_kg                     0
# package_volume_cbm                    0
# order_value_cny                       0
# declared_value_usd                    0
# warehouse_inventory_level             0
# warehouse_capacity_utilization_pct    0
# ...
